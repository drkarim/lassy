# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# /Users/rashedkarim/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
df_data = pd.read_csv('./data/encirclement/FV_LPV_circ.csv')

# %%
df_data.head(2)
# Out:
#    MainVertexSeq  VertexID        X        Y        Z  VertexDepth  MeshScalar
# 0              0      7423  40.5998  37.3302  8.15213            0       143.2
# 1              0      7423  40.5998  37.3302  8.15213            3       143.2

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
df_data['Y'].head(5)
# Out:
# 0    1.000000e-10
# 1    1.000000e-10
# 2    1.727320e+01
# 3    1.787240e+01
# 4    1.711540e+01
# Name: Y, dtype: float64

# %%
df_data.describe()
# Out:
#        MainVertexSeq     VertexID             X             Y            Z  \
# count    2391.000000  2391.000000  2.391000e+03  2.391000e+03  2391.000000
# mean       70.278126  3787.294437  2.741578e+01  2.539945e+01    -9.459983
# std        40.659264  2717.433411  9.544559e+00  1.503381e+01    13.412695
# min         0.000000     0.000000  1.000000e-10  1.000000e-10   -29.077100
# 25%        35.000000  1149.000000  2.412985e+01  8.311020e+00   -22.689200
# 50%        70.000000  3324.000000  2.770150e+01  3.278950e+01   -11.836600
# 75%       106.000000  6900.000000  3.174240e+01  3.911260e+01     6.496470
# max       140.000000  8474.000000  5.019410e+01  4.145310e+01    12.875100
#
#        VertexDepth   MeshScalar
# count  2391.000000  2391.000000
# mean      1.230029   117.709578
# std       0.642785    20.873671
# min       0.000000    -1.000000
# 25%       1.000000   100.143000
# 50%       1.000000   112.000000
# 75%       1.000000   135.381000
# max       3.000000   165.333000

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(df_data['X'], df_data['Y'], df_data['Z'])
plt.show()

# %%
df_data_scalars = pd.concat([df_data['MainVertexSeq'], df_data['MeshScalar']], axis=1)

# %%
df_data_scalars.head(5)
# Out:
#    MainVertexSeq  MeshScalar
# 0              0     143.200
# 1              0     143.200
# 2              0     146.000
# 3              0     148.714
# 4              0     151.857

# %%
ax = sns.boxplot(x="MainVertexSeq", y="MeshScalar", data=df_data_scalars)

# %%
df_data['MainVertexSeq'].nunique()
# Out:
# 141

# %%
df_data['MainVertexSeq'].describe()
# Out:
# count    2391.000000
# mean       70.278126
# std        40.659264
# min         0.000000
# 25%        35.000000
# 50%        70.000000
# 75%       106.000000
# max       140.000000
# Name: MainVertexSeq, dtype: float64

# %%
g1 = df_data.groupby(['MainVertexSeq']).median()
g1 = g1.reset_index()

# %%
g1.head(2)
# Out:
#    MainVertexSeq  VertexID        X         Y        Z  VertexDepth  \
# 0              0      14.5  20.0636  17.84595 -28.7193          1.0
# 1              1     369.0  32.2025  21.14630 -26.5694          1.0
#
#    MeshScalar
# 0    90.66665
# 1    92.33330

# %%
ax = sns.regplot(x="MainVertexSeq", y="MeshScalar", data=g1)

# %%
ax = sns.tsplot(data=g1['MeshScalar'])

# %%
df_data_SM = pd.read_csv('./data/encirclement/SM_RPV_line.csv')

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(df_data_SM['X'], df_data_SM['Y'], df_data_SM['Z'])
plt.show()

# %%
df_data_scalars = pd.concat([df_data_SM['MainVertexSeq'], df_data_SM['MeshScalar']], axis=1)

# %%
g1 = df_data_SM.groupby(['MainVertexSeq']).median()
g1 = g1.reset_index()

# %%
ax = sns.tsplot(data=g1['MeshScalar'])
