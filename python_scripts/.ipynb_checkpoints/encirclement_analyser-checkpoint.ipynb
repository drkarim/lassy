# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
from mpl_toolkits.mplot3d import Axes3D
from sklearn.model_selection import train_test_split
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# /Users/rashedkarim/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
df_data = pd.read_csv('./data/encirclement/AW_RPV_circle.csv')

# %%
df_data.describe()
# Out:
#        MainVertexSeq      VertexID            X            Y            Z  \
# count    2043.000000   2043.000000  2043.000000  2043.000000  2043.000000
# mean       59.555556   8394.457660   -31.954544   -10.177644     3.171557
# std        34.562301   2855.023714     2.569754     8.941109    10.598426
# min         0.000000   4252.000000   -38.710200   -24.509000   -12.840800
# 25%        29.000000   5861.000000   -33.755100   -19.062100    -6.106485
# 50%        60.000000   7810.000000   -31.667600    -8.843990     1.654580
# 75%        90.000000  11047.000000   -29.909200    -1.124780    12.962200
# max       119.000000  13388.000000   -26.766200     1.962160    20.827700
#
#        VertexDepth   MeshScalar
# count  2043.000000  2043.000000
# mean      1.227117   109.334815
# std       0.640847    32.503140
# min       0.000000     0.000000
# 25%       1.000000   104.619000
# 50%       1.000000   112.667000
# 75%       1.000000   123.600000
# max       3.000000   170.000000

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(df_data['X'], df_data['Y'], df_data['Z'])
plt.show()

# %%
df_data_scalars = pd.concat([df_data['MainVertexSeq'], df_data['MeshScalar']], axis=1)

# %%
ax = sns.boxplot(x="MainVertexSeq", y="MeshScalar", data=df_data_scalars)

# %%
g1 = df_data.groupby(['MainVertexSeq']).median()
g1 = g1.reset_index()

# %%
g1.head(2)
# Out:
#    MainVertexSeq  VertexID         X        Y         Z  VertexDepth  \
# 0              0    4487.5 -29.62640 -6.33966 -11.97625          1.0
# 1              1    4492.0 -29.50605 -5.85656 -11.76310          1.0
#
#    MeshScalar
# 0      115.75
# 1      115.75

# %%
ax = sns.tsplot(data=g1['MeshScalar'])

# %%
center_data = [df_data['X'].mean(), df_data['Y'].mean(), df_data['Z'].mean()]

# %%
center_data
# Out:
# [-31.95454444444453, -10.177643953352947, 3.1715572881057232]

# %%
df_data_scalars = pd.concat([df_data['MainVertexSeq'], df_data['MeshScalar']], axis=1)

# %%
g1 = df_data.groupby(['MainVertexSeq']).median()
g1 = g1.reset_index()

# %%
ax = sns.tsplot(data=g1['MeshScalar'])

# %%
def unit_vector(vector):
    """ Returns the unit vector of the vector.  """
    return vector / np.linalg.norm(vector)

def angle_between(v1, v2):
    """ Returns the angle in radians between vectors 'v1' and 'v2'::

            >>> angle_between((1, 0, 0), (0, 1, 0))
            1.5707963267948966
            >>> angle_between((1, 0, 0), (1, 0, 0))
            0.0
            >>> angle_between((1, 0, 0), (-1, 0, 0))
            3.141592653589793
    """
    v1_u = unit_vector(v1)
    v2_u = unit_vector(v2)
    return np.arccos(np.clip(np.dot(v1_u, v2_u), -1.0, 1.0))

# %%
def point_theta(center, A):
    thetas = []; 
    Ref_pt = [A.iloc[0]['X'], A.iloc[0]['Y'], A.iloc[0]['Z']] 
    for index, row in A.iterrows():
        pt = [row['X'], row['Y'], row['Z']]
        theta = angle_between(Ref_pt, pt)
        thetas.append(theta)
    return thetas

# %%
thetas = point_theta(center_data, df_data)

# %%
thetas_df = pd.Series(thetas, name='theta');

# %%
df_data_with_theta = pd.concat([df_data, thetas_df], axis=1)

# %%
sns.tsplot(df_data_with_theta['theta'])

# %%
df_data_with_thetas_sorted = df_data_with_theta.sort_values(by='theta')

# %%
df_data_with_thetas_sorted.head(10)
# Out:
#      MainVertexSeq  VertexID        X        Y        Z  VertexDepth  \
# 0                0      4482 -29.5702 -6.36556 -11.9955            0
# 1                0      4482 -29.5702 -6.36556 -11.9955            3
# 179             10      4482 -29.5702 -6.36556 -11.9955            2
# 36               2      4482 -29.5702 -6.36556 -11.9955            1
# 22               1      4482 -29.5702 -6.36556 -11.9955            1
# 182             10      4487 -29.4419 -5.85656 -11.8139            1
# 34               2      4487 -29.4419 -5.85656 -11.8139            2
# 9                0      4487 -29.4419 -5.85656 -11.8139            1
# 19               1      4487 -29.4419 -5.85656 -11.8139            3
# 18               1      4487 -29.4419 -5.85656 -11.8139            0
#
#      MeshScalar         theta
# 0       117.167  2.107342e-08
# 1       117.167  2.107342e-08
# 179     117.167  2.107342e-08
# 36      117.167  2.107342e-08
# 22      117.167  2.107342e-08
# 182     115.000  1.481398e-02
# 34      115.000  1.481398e-02
# 9       115.000  1.481398e-02
# 19      115.000  1.481398e-02
# 18      115.000  1.481398e-02

# %%
sns.tsplot(df_data_with_thetas_sorted['theta'])

# %%
sns.tsplot(df_data_with_thetas_sorted['MeshScalar'])

# %%
df_data_with_thetas_sorted.head(15)
# Out:
#      MainVertexSeq  VertexID        X        Y        Z  VertexDepth  \
# 0                0      4482 -29.5702 -6.36556 -11.9955            0
# 1                0      4482 -29.5702 -6.36556 -11.9955            3
# 179             10      4482 -29.5702 -6.36556 -11.9955            2
# 36               2      4482 -29.5702 -6.36556 -11.9955            1
# 22               1      4482 -29.5702 -6.36556 -11.9955            1
# 182             10      4487 -29.4419 -5.85656 -11.8139            1
# 34               2      4487 -29.4419 -5.85656 -11.8139            2
# 9                0      4487 -29.4419 -5.85656 -11.8139            1
# 19               1      4487 -29.4419 -5.85656 -11.8139            3
# 18               1      4487 -29.4419 -5.85656 -11.8139            0
# 168             10      4706 -30.2520 -6.82380 -11.7123            3
# 167             10      4706 -30.2520 -6.82380 -11.7123            0
# 162              9      4706 -30.2520 -6.82380 -11.7123            1
# 150              8      4706 -30.2520 -6.82380 -11.7123            1
# 30               1      4706 -30.2520 -6.82380 -11.7123            1
#
#      MeshScalar         theta
# 0       117.167  2.107342e-08
# 1       117.167  2.107342e-08
# 179     117.167  2.107342e-08
# 36      117.167  2.107342e-08
# 22      117.167  2.107342e-08
# 182     115.000  1.481398e-02
# 34      115.000  1.481398e-02
# 9       115.000  1.481398e-02
# 19      115.000  1.481398e-02
# 18      115.000  1.481398e-02
# 168     118.833  1.882078e-02
# 167     118.833  1.882078e-02
# 162     118.833  1.882078e-02
# 150     118.833  1.882078e-02
# 30      118.833  1.882078e-02

# %%
df_data_with_thetas_sorted_nodupes = df_data_with_thetas_sorted.drop_duplicates(subset='VertexID', keep='last');

# %%
sns.tsplot(pd.rolling_mean(df_data_with_thetas_sorted_nodupes['MeshScalar'],20))

# %%
df_data_with_thetas_sorted_nodupes.describe()
# Out:
#        MainVertexSeq      VertexID           X           Y           Z  \
# count     612.000000    612.000000  612.000000  612.000000  612.000000
# mean       59.753268   8421.892157  -31.937437  -10.398865    3.269082
# std        34.836813   2903.703717    2.728574    8.886861   10.757137
# min         0.000000   4252.000000  -38.710200  -24.509000  -12.840800
# 25%        29.000000   5856.750000  -33.858625  -18.987025   -6.394505
# 50%        60.500000   7811.500000  -31.640600   -9.545580    1.825005
# 75%        91.000000  11249.250000  -29.816550   -1.582000   13.498525
# max       119.000000  13388.000000  -26.766200    1.962160   20.827700
#
#        VertexDepth  MeshScalar         theta
# count   612.000000  612.000000  6.120000e+02
# mean      1.179739  108.129289  5.286550e-01
# std       0.524722   33.919835  2.930704e-01
# min       0.000000    0.000000  2.107342e-08
# 25%       1.000000  104.482250  2.764798e-01
# 50%       1.000000  112.000000  5.335088e-01
# 75%       1.000000  123.374750  8.119940e-01
# max       3.000000  170.000000  9.799471e-01
